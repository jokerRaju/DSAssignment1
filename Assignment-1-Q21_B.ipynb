# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
dt=pd.read_csv(r"C:\Users\nraje\OneDrive\Desktop\Data Science Assignments\Basic Statistics Level 1\wc-at.csv")

# %%
print(dt.mean())
print(dt.median())
print(dt.mode())
# Out:
# Waist     91.901835
# AT       101.894037
# dtype: float64
# Waist    90.80
# AT       96.54
# dtype: float64
#    Waist     AT
# 0   94.5  121.0
# 1  106.0  123.0
# 2  108.5    NaN

# %%
sns.distplot(dt['Waist'])
plt.show()
# Out:
# C:\Users\nraje\AppData\Local\Temp\ipykernel_21360\1615508523.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dt['Waist'])

# %%
sns.distplot(dt['AT'])
plt.show()
# Out:
# C:\Users\nraje\AppData\Local\Temp\ipykernel_21360\4160800194.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dt['AT'])

# %%
sns.boxplot(dt['AT'])
plt.show()

# %%
# mean> median, right whisker is larger than left whisker, data is positively skewed.

# %%
sns.boxplot(dt['Waist'])
plt.show()

# %%
## mean> median, both the whisker are of same lenght, median is slightly shifted towards left.
## Data is fairly symetrically distrubuted.
