# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\nraje\OneDrive\Desktop\Data Science Assignments\Basic Statistics Level 1\Q9_b.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  81 non-null     int64
#  1   SP          81 non-null     float64
#  2   WT          81 non-null     float64
# dtypes: float64(2), int64(1)
# memory usage: 2.0 KB

# %%
#Skewness
df.skew()[['SP','WT']]
# Out:
# SP    1.611450
# WT   -0.614753
# dtype: float64

# %%
#Kurtosis
df.kurtosis()[['SP','WT']]
# Out:
# SP    2.977329
# WT    0.950291
# dtype: float64

# %%
plt.hist(x='SP',data=df)
plt.show()

# %% [markdown]
# Right Skewed or positively skewed

# %%
plt.boxplot(x='WT',data=df)
plt.show()

# %% [markdown]
# Have outliers or extreme values with Right Skewed or positively skewed
